# %% [markdown]
# # [Practice Notebook] Model Quality and improvements

# %% [markdown]
# 1.Data Importation

# %%
#Import data 
import pandas as pd
df=pd.read_csv('https://bit.ly/DiabetesDS')
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %% [markdown]
# 2.Data Exploration

# %%
#check the last five data 
df.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# 761                     0.403   43        1
# 762                     0.142   33        0
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
#Check the sample data
df.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 348            3       99             62             19       74  21.8
# 173            1       79             60             42       48  43.5
# 481            0      123             88             37        0  35.2
# 156            2       99             52             15       94  24.6
# 722            1      149             68             29      127  29.3
# 452            0       91             68             32      210  39.9
# 457            5       86             68             28       71  30.2
# 658           11      127            106              0        0  39.0
# 432            1       80             74             11       60  30.0
# 7             10      115              0              0        0  35.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 348                     0.279   26        0
# 173                     0.678   23        0
# 481                     0.197   29        0
# 156                     0.637   21        0
# 722                     0.349   42        1
# 452                     0.381   25        0
# 457                     0.364   24        0
# 658                     0.190   51        0
# 432                     0.527   22        0
# 7                       0.134   29        0

# %%
#Check the data types
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
#Check data shape
df.shape
# Out:
# (768, 9)

# %%
#Plot Histogram

import matplotlib.pyplot as plt
import pandas as pd

#Plots in matplotlib reside within a figure object, use plt.figure to create new figure
fig=plt.figure()

#Create one or more subplots using add_subplot, because you can't create blank figure
ax = fig.add_subplot(1,1,1)
#Variable
ax.hist(df['Outcome'],bins = 5)

#Labels and Tit
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('#Pregnancies')
plt.show()

# %% [markdown]
# 3.Data Cleaning

# %%
#Check duplicate
df.duplicated().sum()
# Out:
# 0

# %%
#Check null column
df.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# 1                       False  False    False
# 2                       False  False    False
# 3                       False  False    False
# 4                       False  False    False
# ..                        ...    ...      ...
# 763                     False  False    False
# 764                     False  False    False
# 765                     False  False    False
# 766                     False  False    False
# 767                     False  False    False
#
# [768 rows x 9 columns]

# %% [markdown]
# 4.Data preparation

# %%
# Drop the columns where all elements are missing values:
df.dropna(axis=1, how='all')

# Drop the columns where any of the elements are missing values
df.dropna(axis=1, how='any')

# Keep only the rows which contain 2 missing values maximum
df.dropna(thresh=2)

# Drop the columns where any of the elements are missing values
df.dropna(axis=1, how='any')

# Fill all missing values with the mean of the particular column
df.fillna(df.mean())
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
#Processing data using DecisionTreeClassifier
import pandas as pd
from sklearn.tree import DecisionTreeClassifier


features = df.drop(['Outcome'], axis=1)
target = df['Outcome']

model = DecisionTreeClassifier(random_state=12345)

model.fit(features, target)
model.score(features, target)
# Out:
# 1.0

# %%
#Data modelling using RandomForest

import pandas as pd
from sklearn.ensemble import RandomForestClassifier


features = df.drop(['Outcome'], axis=1)
target = df['Outcome']

model = RandomForestClassifier(random_state=12345,n_estimators=3)

model.fit(features, target)
model.score(features, target)
# Out:
# 0.9466145833333334

# %%
#Data Modelling using Logistic Regression

from sklearn.linear_model import LogisticRegression


features = df.drop(['Outcome'], axis=1)
target = df['Outcome']

model = LogisticRegression(random_state=42, solver='liblinear')

model.fit(features, target)
model.score(features, target)
# Out:
# 0.7747395833333334

# %%
#Accuracy 
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

features = df.drop(['Outcome'], axis=1)
target = df['Outcome']

model = DecisionTreeClassifier(random_state=12345)

model.fit(features, target)
model.score(features, target)
predictions=model.predict(features)
print(accuracy_score(target, predictions))
# Out:
# 1.0

# %%
#Spliting the data
from sklearn.model_selection import train_test_split
df_train, df_valid = train_test_split(df, test_size=0.25, random_state=12345)


features_train = df_train.drop(['Outcome'], axis=1)
target_train = df_train['Outcome']
features_valid = df_valid.drop(['Outcome'], axis=1)
target_valid = df_valid['Outcome']


print(features_train.shape)
print(target_train.shape)
print(features_valid.shape)
print(target_valid.shape)
# Out:
# (576, 8)
# (576,)
# (192, 8)
# (192,)

# %%
#Tuning Hyperparameters DecisionTreeClassifier

import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split


df_train, df_valid = train_test_split(df, test_size=0.25, random_state=12345)

features_train = df_train.drop(['Outcome'], axis=1)
target_train = df_train['Outcome']
features_valid = df_valid.drop(['Outcome'], axis=1)
target_valid = df_valid['Outcome']

for depth in range(1, 10):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth)
    model.fit(features_train, target_train)
    predictions_valid = model.predict(features_valid)
    print('max_depth =', depth, ': ', end='')
    print(accuracy_score(target_valid, predictions_valid))
# Out:
# max_depth = 1 : 0.7708333333333334
# max_depth = 2 : 0.7708333333333334
# max_depth = 3 : 0.7604166666666666
# max_depth = 4 : 0.75
# max_depth = 5 : 0.8177083333333334
# max_depth = 6 : 0.8229166666666666
# max_depth = 7 : 0.765625
# max_depth = 8 : 0.7604166666666666
# max_depth = 9 : 0.7552083333333334

# %%
#Tuning Hyperparameters RandomForestClassifier

import pandas as pd
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split

df_train, df_valid = train_test_split(df, test_size=0.25, random_state=12345)

features_train = df_train.drop(['Outcome'], axis=1)
target_train = df_train['Outcome']
features_valid = df_valid.drop(['Outcome'], axis=1)
target_valid = df_valid['Outcome']

model = RandomForestClassifier(random_state=12345, n_estimators=3)
model.fit(features_train, target_train)
model.score(features_valid, target_valid)
# Out:
# 0.7083333333333334

# %%
#Tuning Hyperparameters Logistic Regression
import pandas as pd
from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import train_test_split

df_train, df_valid = train_test_split(df, test_size=0.25, random_state=12345)

features_train = df_train.drop(['Outcome'], axis=1)
target_train = df_train['Outcome']
features_valid = df_valid.drop(['Outcome'], axis=1)
target_valid = df_valid['Outcome']

model = LogisticRegression(random_state=12345, solver='liblinear')
model.fit(features_train, target_train)
model.score(features_valid, target_valid)
# Out:
# 0.7916666666666666

# %%
# Finding and recommendations
#Random Forest and decision is the most accurate compare to Logistic Regression before training the data

#Tuning Hyperparameters none of them is accurate.

# %% [markdown]
# **Observation**
